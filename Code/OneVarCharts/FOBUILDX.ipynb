# %% [markdown]
# <a href="https://colab.research.google.com/github/GavinButts/Fall-Data-Challenge-2022/blob/main/Code/OneVarCharts/FOBUILDX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
#Question: In the past week, has anyone in your family done the following things with this child? 
#             d. Worked on a project like building, making, or fixing something



csv = pd.read_csv('CuratedData.csv')
FOBUILDX = []
for element in csv["FOBUILDX"]:
    if element != -1:
        if element == 1:
            FOBUILDX.append("Yes")
        if element == 2:
            FOBUILDX.append("No")
        
res = sns.countplot(x=FOBUILDX, palette="pastel")
